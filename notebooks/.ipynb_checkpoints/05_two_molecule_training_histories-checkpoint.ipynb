# %%
import matplotlib.pylab as plt
import numpy as np
import seaborn as sns; sns.set()
# %matplotlib inline

import keras
from keras import objectives
from keras.callbacks import EarlyStopping
from keras.models import Sequential, Model
from keras.layers import Dense, Dropout, Input, Multiply, Add
from keras.optimizers import Adam, Nadam
import salty
from numpy import array
from numpy import argmax
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.decomposition import PCA
from random import shuffle
import pandas as pd
import random

#Keras build
from keras import backend as K
from keras.objectives import binary_crossentropy #objs or losses
from keras.models import Model
from keras.layers import Input, Dense, Lambda, Layer
from keras.layers.core import Dense, Activation, Flatten, RepeatVector
from keras.layers.wrappers import TimeDistributed
from keras.layers.recurrent import GRU
from keras.layers.convolutional import Convolution1D

#cation data
cations = pd.read_csv('../data/cations.csv')
cations = cations['smiles_string']
salts = pd.read_csv('../data/salts.csv')
salts = salts['smiles_string']
categories = pd.read_csv('../data/categories.csv')
categories = categories['category']
coldic = pd.read_csv('../data/coldic.csv')
coldic = coldic.to_dict(orient='records')[0]
salt_coldic = pd.read_csv('../data/salt_coldic.csv')
salt_coldic = salt_coldic.to_dict(orient='records')[0]
salt_categories = pd.read_csv('../data/salt_categories.csv')
salt_categories = salt_categories['category']
density_coldic = pd.read_csv('../data/density_coldic.csv')
density_coldic = density_coldic.to_dict(orient='records')[0]
density_categories = pd.read_csv('../data/density_categories.csv')
density_categories = density_categories['category']

#training array info
smile_max_length = 105
import json
f = open("../data/salt_char_to_index.json","r")
char_to_index = json.loads(f.read())
char_set = set(char_to_index.keys())
char_list = list(char_to_index.keys())
chars_in_dict = len(char_list)

#supporting functions
import sys
sys.path.insert(0, '../')
from scripts import *

from matplotlib import colors
from itertools import cycle

def my_colors():
    """
    return a tableau colors iterable
    """
    tab = cycle(colors.TABLEAU_COLORS)
    return tab
# Out:
# /home/wesleybeckner/anaconda3/envs/py36/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
import os
histories = []
for root, dirs, files in os.walk("../models/histories"):  
    for filename in files:
        if 'history' in filename:
            if 'gen' in filename:
                if 'GDB17_mix_pure' in filename:
                    histories.append(filename)

# %%
histories.sort()

# %%
from matplotlib.ticker import MaxNLocator  ## Import MaxNLocator
with plt.style.context('seaborn-whitegrid'):
    fig, ax = plt.subplots(1, figsize=(4.3,4.3), dpi=300)
    tab = my_colors()
    for i in range(3):
        col=next(tab)
        with open('../models/histories/{}'.format(histories[i]), 'r') as f:
            hist = json.load(f)
        cat = []
        ani = []
        for epoch in hist:
            if i == 0:
                ani.append(epoch['decoded_anion_mean_acc'][0])
                cat.append(epoch['decoded_cation_mean_acc'][0])
            else:
                ani.append(epoch['anion_decoded_mean_acc'][0])
                cat.append(epoch['cation_decoded_mean_acc'][0])
        ax.plot(np.arange(1,21), ani, ls='--', label="Gen {}: Anion".format(i+1), c=col)
        ax.plot(np.arange(1,21), cat, ls='-', label="           Cation".format(i+1), c=col)
        ax.set_xlim(1,20,1)
        ax.set_ylim(0.7,1)
        ax.set_ylabel('Accuracy')
        ax.set_xlabel('Hundreds of Thousands of Training Examples')
        
        ax.legend(loc=2, frameon=True)
    ax.plot([10,10],[0.6,1.1], ls=':', c='tab:grey')
    ax.plot([15,15],[0.6,1.1], ls=':', c='tab:grey')
    x_ax = ax.axes.get_xaxis()  ## Get X axis
    x_ax.set_major_locator(MaxNLocator(integer=True))  ## Set major locators to integer values
    fig.tight_layout()
    plt.grid()

# %%
import os
histories = []
for root, dirs, files in os.walk("../models/histories"):  
    for filename in files:
        if 'history' in filename:
            if 'gen3vae' in filename:
                if '100' in filename:
                    if 'melting' not in filename:
                        if (filename.split('_')[3] == '100.json') or (filename.split('_')[3] == 'conductivity'):
                            histories.append(filename)

# %%
histories
# Out:
# ['history_gen3vae_viscosity_100.json',
#  'history_gen3vae_cpt_100.json',
#  'history_gen3vae_density_100.json',
#  'history_gen3vae_thermal_conductivity_100.json']

# %%
from matplotlib.ticker import MaxNLocator  ## Import MaxNLocator
def make_patch_spines_invisible(ax):
    ax.set_frame_on(True)
    ax.patch.set_visible(False)
    for sp in ax.spines.values():
        sp.set_visible(False)
        
with plt.style.context('seaborn-whitegrid'):
    fig, ax = plt.subplots(1, figsize=(5,5), dpi=300)
    ax2 = ax.twinx()
    tab = my_colors()
    for i in range(4):
        col=next(tab)
        with open('../models/histories/{}'.format(histories[i]), 'r') as f:
            hist = json.load(f)


        ax2.plot(np.arange(1,101,1), hist['val_anion_decoded_mean_acc'], ls='--', label=" anion {}".format(histories[i].split('_')[2]), c=col)
        ax2.plot(np.arange(1,101,1), hist['val_cation_decoded_mean_acc'], ls='-', label="cation {}".format(histories[i].split('_')[2]), c=col)
        ax.plot(np.arange(1,101,1), hist['val_qspr_mean_squared_error'], ls=':', label="   qspr {}".format(histories[i].split('_')[2]), c=col)
        
        ax.set_xlim(0,100,1)
        ax2.set_ylim(0,1)
#         ax2.set_ylim(0.7,1.1)
        
        ax.set_ylabel('MSE')
        ax2.set_ylabel('Accuracy')
        ax.set_xlabel('Epochs')
        
        h1, l1 = ax.get_legend_handles_labels()
        h2, l2 = ax2.get_legend_handles_labels()
        ax2.legend(h1+h2, l1+l2, frameon=True, bbox_to_anchor=(1.7, .85))
        
    ax2.plot([10,10],[0,1], ls=':', c='tab:grey')
    ax2.plot([30,30],[0,1], ls=':', c='tab:grey')
    
    x_ax = ax.axes.get_xaxis()  ## Get X axis
    x_ax.set_major_locator(MaxNLocator(integer=True))  ## Set major locators to integer values
    ax.set_title('Validation History')
    ax2.grid()
    ax.grid()
    fig.tight_layout()

# %%
from matplotlib.ticker import MaxNLocator  ## Import MaxNLocator
def make_patch_spines_invisible(ax):
    ax.set_frame_on(True)
    ax.patch.set_visible(False)
    for sp in ax.spines.values():
        sp.set_visible(False)
        
with plt.style.context('seaborn-whitegrid'):
    fig, ax = plt.subplots(1, figsize=(5,5), dpi=300)
    ax2 = ax.twinx()
    tab = my_colors()
    for i in range(4):
        col=next(tab)
        with open('../models/histories/{}'.format(histories[i]), 'r') as f:
            hist = json.load(f)

        ax2.plot(np.arange(1,101,1), hist['anion_decoded_mean_acc'], ls='--', label=" anion {}".format(histories[i].split('_')[2]), c=col)
        ax2.plot(np.arange(1,101,1), hist['cation_decoded_mean_acc'], ls='-', label="cation {}".format(histories[i].split('_')[2]), c=col)
        ax.plot(np.arange(1,101,1), hist['qspr_mean_squared_error'], ls=':', label="   qspr {}".format(histories[i].split('_')[2]), c=col)
               
        ax.set_xlim(0,100,1)
        ax2.set_ylim(0,1)
        ax.set_ylabel('MSE')
        ax2.set_ylabel('Accuracy')
        ax.set_xlabel('Epochs')
        
        h1, l1 = ax.get_legend_handles_labels()
        h2, l2 = ax2.get_legend_handles_labels()
        ax2.legend(h1+h2, l1+l2, frameon=True, framealpha=0.8, loc='right')#, bbox_to_anchor=(1.7, .85))

    ax.set_title('Training History')
    x_ax = ax.axes.get_xaxis()  ## Get X axis
    x_ax.set_major_locator(MaxNLocator(integer=True))  ## Set major locators to integer values
    ax2.grid()
    ax.grid()
    fig.tight_layout()
#     plt.grid()

# %%
fig.savefig('assets/gen123_training_hist.svg', dpi=300)

# %%
fig, ax = plt.subplots(1, figsize=(10,10))
histories.sort()            
for key, item in enumerate(histories):
    print(histories[key])
    f = open("../models/{}".format(histories[key]),"r")
    history = json.loads(f.read())
    for hist in history:
        print(hist)
        try:
            ax.plot(hist['decoded_cation_mean_acc'], label='val acc')
            ax.plot(hist['decoded_anion_mean_acc'], label = 'acc')
        except:
            ax.plot(hist['cation_decoded_mean_acc'], label='val acc')
            ax.plot(hist['anion_decoded_mean_acc'], label = 'acc')
            
        

    fig, ax = plt.subplots(1, figsize=(10,10))
    

    ax.set_ylim(0,2)
    ax.set_title(item)
    ax.legend()
#     except:pass
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# history_gen1_2mol_1mil_GDB17_mix_pure.json
# {'decoded_cation_mean_loss': [2.2092214672851562], 'decoded_cation_mean_acc': [0.7066377421483397], 'decoded_anion_mean_acc': [0.7067117740881443], 'decoded_anion_mean_loss': [2.211126968269348], 'loss': [4.4203484349823]}
# {'decoded_cation_mean_loss': [2.158374296760559], 'decoded_cation_mean_acc': [0.7106159678840637], 'decoded_anion_mean_acc': [0.7125814513969422], 'decoded_anion_mean_loss': [2.131297709732056], 'loss': [4.289672004470825]}
# {'decoded_cation_mean_loss': [2.1821408116149903], 'decoded_cation_mean_acc': [0.7093077417230607], 'decoded_anion_mean_acc': [0.7101222575187683], 'decoded_anion_mean_loss': [2.173652139968872], 'loss': [4.355792947998047]}
# {'decoded_cation_mean_loss': [2.2234405721664428], 'decoded_cation_mean_acc': [0.7040672578239441], 'decoded_anion_mean_acc': [0.7026545160675048], 'decoded_anion_mean_loss': [2.248893270301819], 'loss': [4.472333840789795]}
# {'decoded_cation_mean_loss': [2.129129978981018], 'decoded_cation_mean_acc': [0.7124491932106018], 'decoded_anion_mean_acc': [0.7118296776199341], 'decoded_anion_mean_loss': [2.1336263105010986], 'loss': [4.262756293334961]}
# {'decoded_cation_mean_loss': [2.1143305489730837], 'decoded_cation_mean_acc': [0.714009515953064], 'decoded_anion_mean_acc': [0.7142725811576843], 'decoded_anion_mean_loss': [2.1126591704940796], 'loss': [4.22698971748352]}
# {'decoded_cation_mean_loss': [2.101111889305115], 'decoded_cation_mean_acc': [0.7159817741775513], 'decoded_anion_mean_acc': [0.7166645158004761], 'decoded_anion_mean_loss': [2.0968657092285157], 'loss': [4.197977596282959]}
# {'decoded_cation_mean_loss': [2.096934219970703], 'decoded_cation_mean_acc': [0.7169085483551025], 'decoded_anion_mean_acc': [0.7175459674263001], 'decoded_anion_mean_loss': [2.0917962036132813], 'loss': [4.188730425338745]}
# {'decoded_cation_mean_loss': [2.087922140426636], 'decoded_cation_mean_acc': [0.7182346775245666], 'decoded_anion_mean_acc': [0.7189983870697021], 'decoded_anion_mean_loss': [2.0824239026260374], 'loss': [4.17034604347229]}
# {'decoded_cation_mean_loss': [2.0856739503097534], 'decoded_cation_mean_acc': [0.718755484046936], 'decoded_anion_mean_acc': [0.7194316125297546], 'decoded_anion_mean_loss': [2.0814818577194214], 'loss': [4.1671558097076415]}
# {'decoded_cation_mean_loss': [1.9255556174850463], 'decoded_cation_mean_acc': [0.7576612900733948], 'decoded_anion_mean_acc': [0.7408948387145996], 'decoded_anion_mean_loss': [1.9595522483062744], 'loss': [3.8851078675079345]}
# {'decoded_cation_mean_loss': [1.9013621924209594], 'decoded_cation_mean_acc': [0.7588941939163208], 'decoded_anion_mean_acc': [0.7482280647087097], 'decoded_anion_mean_loss': [1.8936075815963744], 'loss': [3.794969772338867]}
# {'decoded_cation_mean_loss': [1.901580537071228], 'decoded_cation_mean_acc': [0.7584569352149964], 'decoded_anion_mean_acc': [0.7528825806045533], 'decoded_anion_mean_loss': [1.8614828420639038], 'loss': [3.763063377456665]}
# {'decoded_cation_mean_loss': [1.8944199480056763], 'decoded_cation_mean_acc': [0.7589840316581726], 'decoded_anion_mean_acc': [0.7604498386192322], 'decoded_anion_mean_loss': [1.8155554191207885], 'loss': [3.709975368347168]}
# {'decoded_cation_mean_loss': [1.8900549404525757], 'decoded_cation_mean_acc': [0.7593848390197754], 'decoded_anion_mean_acc': [0.768106935005188], 'decoded_anion_mean_loss': [1.769071650981903], 'loss': [3.6591265911865234]}
# {'decoded_cation_mean_loss': [1.579888014907837], 'decoded_cation_mean_acc': [0.8031766131973267], 'decoded_anion_mean_acc': [0.8810632263946533], 'decoded_anion_mean_loss': [1.013315820198059], 'loss': [2.593203835220337]}
# {'decoded_cation_mean_loss': [1.5848391021347046], 'decoded_cation_mean_acc': [0.801935161113739], 'decoded_anion_mean_acc': [0.9121143546867371], 'decoded_anion_mean_loss': [0.7872127039718628], 'loss': [2.372051806907654]}
# {'decoded_cation_mean_loss': [1.5803917485046386], 'decoded_cation_mean_acc': [0.8019729029655457], 'decoded_anion_mean_acc': [0.9326693548965455], 'decoded_anion_mean_loss': [0.6377442374515534], 'loss': [2.2181359853744507]}
# {'decoded_cation_mean_loss': [1.5760919627380372], 'decoded_cation_mean_acc': [0.8020024192237853], 'decoded_anion_mean_acc': [0.9473790322303772], 'decoded_anion_mean_loss': [0.5188771408033371], 'loss': [2.09496910446167]}
# {'decoded_cation_mean_loss': [1.575400532951355], 'decoded_cation_mean_acc': [0.8021632256126404], 'decoded_anion_mean_acc': [0.9512056453132629], 'decoded_anion_mean_loss': [0.4796495593738556], 'loss': [2.055050091590881]}
# history_gen2_2mol_1mil_GDB17_mix_pure.json
# {'anion_decoded_mean_acc': [0.6920117741644383], 'cation_decoded_mean_acc': [0.7050316129809618], 'loss': [4.66977727722168], 'cation_decoded_mean_loss': [2.2336939775466917], 'anion_decoded_mean_loss': [2.4360832978057863]}
# {'anion_decoded_mean_acc': [0.69626532289505], 'cation_decoded_mean_acc': [0.715755484046936], 'loss': [4.477320719604492], 'cation_decoded_mean_loss': [2.10159937084198], 'anion_decoded_mean_loss': [2.3757213439178466]}
# {'anion_decoded_mean_acc': [0.6931259685850143], 'cation_decoded_mean_acc': [0.7068064519453049], 'loss': [4.703925694580078], 'cation_decoded_mean_loss': [2.2599568239593504], 'anion_decoded_mean_loss': [2.443968871459961]}
# {'anion_decoded_mean_acc': [0.70736209690094], 'cation_decoded_mean_acc': [0.7092675808525085], 'loss': [4.405279793548584], 'cation_decoded_mean_loss': [2.185883693771362], 'anion_decoded_mean_loss': [2.2193961025619506]}
# {'anion_decoded_mean_acc': [0.7078180650138854], 'cation_decoded_mean_acc': [0.7092459677505493], 'loss': [4.38319384765625], 'cation_decoded_mean_loss': [2.18427052154541], 'anion_decoded_mean_loss': [2.1989233268737793]}
# {'anion_decoded_mean_acc': [0.7089740321350098], 'cation_decoded_mean_acc': [0.7100430646705628], 'loss': [4.336154810943603], 'cation_decoded_mean_loss': [2.1641769690322876], 'anion_decoded_mean_loss': [2.171977844314575]}
# {'anion_decoded_mean_acc': [0.7104638713645935], 'cation_decoded_mean_acc': [0.7112149989318848], 'loss': [4.30147003578186], 'cation_decoded_mean_loss': [2.1484210670471193], 'anion_decoded_mean_loss': [2.153048970718384]}
# {'anion_decoded_mean_acc': [0.7104064512825012], 'cation_decoded_mean_acc': [0.7113558065032959], 'loss': [4.3027029129028325], 'cation_decoded_mean_loss': [2.1453954565048217], 'anion_decoded_mean_loss': [2.1573074546051028]}
# {'anion_decoded_mean_acc': [0.7108888707351685], 'cation_decoded_mean_acc': [0.7105358066177369], 'loss': [4.308036708297729], 'cation_decoded_mean_loss': [2.1543649897384642], 'anion_decoded_mean_loss': [2.1536717183303833]}
# {'anion_decoded_mean_acc': [0.715003064994812], 'cation_decoded_mean_acc': [0.7131208065605164], 'loss': [4.236279934997558], 'cation_decoded_mean_loss': [2.1235357348251345], 'anion_decoded_mean_loss': [2.112744201812744]}
# {'anion_decoded_mean_acc': [0.734024193763733], 'cation_decoded_mean_acc': [0.7531230647277832], 'loss': [4.58064342010498], 'cation_decoded_mean_loss': [2.299724743309021], 'anion_decoded_mean_loss': [2.2809186779403685]}
# {'anion_decoded_mean_acc': [0.7432364513587951], 'cation_decoded_mean_acc': [0.7537920970726013], 'loss': [4.493747355499267], 'cation_decoded_mean_loss': [2.283877963142395], 'anion_decoded_mean_loss': [2.2098693921661376]}
# {'anion_decoded_mean_acc': [0.7501888709259034], 'cation_decoded_mean_acc': [0.7545951614379883], 'loss': [4.437723794784546], 'cation_decoded_mean_loss': [2.273408054008484], 'anion_decoded_mean_loss': [2.1643157400131225]}
# {'anion_decoded_mean_acc': [0.755000484085083], 'cation_decoded_mean_acc': [0.7553067743682861], 'loss': [4.391962670593261], 'cation_decoded_mean_loss': [2.259711888923645], 'anion_decoded_mean_loss': [2.132250781211853]}
# {'anion_decoded_mean_acc': [0.7593388706970214], 'cation_decoded_mean_acc': [0.7555433871650696], 'loss': [4.318402299575806], 'cation_decoded_mean_loss': [2.2546372842788696], 'anion_decoded_mean_loss': [2.0637650174713134]}
# {'anion_decoded_mean_acc': [0.8444814516639709], 'cation_decoded_mean_acc': [0.8048666126823425], 'loss': [3.9778167389678956], 'cation_decoded_mean_loss': [2.2434864136123656], 'anion_decoded_mean_loss': [1.7343303258132934]}
# {'anion_decoded_mean_acc': [0.8614267739868164], 'cation_decoded_mean_acc': [0.8076585487747192], 'loss': [3.8261374781036377], 'cation_decoded_mean_loss': [2.2116124781036377], 'anion_decoded_mean_loss': [1.61452499835968]}
# {'anion_decoded_mean_acc': [0.8777337098884582], 'cation_decoded_mean_acc': [0.8087854837989807], 'loss': [3.707810968322754], 'cation_decoded_mean_loss': [2.1964952618026734], 'anion_decoded_mean_loss': [1.5113157075881958]}
# {'anion_decoded_mean_acc': [0.8975516131782532], 'cation_decoded_mean_acc': [0.8091803225708007], 'loss': [3.577915587158203], 'cation_decoded_mean_loss': [2.190947045173645], 'anion_decoded_mean_loss': [1.3869685432815553]}
# {'anion_decoded_mean_acc': [0.9062512899017334], 'cation_decoded_mean_acc': [0.8100896774482728], 'loss': [3.5182842308044435], 'cation_decoded_mean_loss': [2.180999691696167], 'anion_decoded_mean_loss': [1.3372845369338988]}
# history_gen3_2mol_1mil_GDB17_mix_pure.json
# {'cation_decoded_mean_acc': [0.7092712902450562], 'anion_decoded_mean_loss': [2.177353358459473], 'cation_decoded_mean_loss': [2.1731796616363526], 'loss': [4.3505330201721195], 'anion_decoded_mean_acc': [0.7080920968967677]}
# {'cation_decoded_mean_acc': [0.7828411293792724], 'anion_decoded_mean_loss': [1.659211781387329], 'cation_decoded_mean_loss': [1.5899104057312012], 'loss': [3.249122188568115], 'anion_decoded_mean_acc': [0.7718790323829651]}
# {'cation_decoded_mean_acc': [0.826156451587677], 'anion_decoded_mean_loss': [1.190219091129303], 'cation_decoded_mean_loss': [1.270239589099884], 'loss': [2.4604586804199218], 'anion_decoded_mean_acc': [0.839316290512085]}
# {'cation_decoded_mean_acc': [0.8474859676170349], 'anion_decoded_mean_loss': [0.9676068307304382], 'cation_decoded_mean_loss': [1.129492642211914], 'loss': [2.0970994752120973], 'anion_decoded_mean_acc': [0.8711225806999207]}
# {'cation_decoded_mean_acc': [0.8718995159721374], 'anion_decoded_mean_loss': [0.8303270207977295], 'cation_decoded_mean_loss': [0.9487457077217102], 'loss': [1.7790727283096313], 'anion_decoded_mean_acc': [0.8903641940879822]}
# {'cation_decoded_mean_acc': [0.8864217742538452], 'anion_decoded_mean_loss': [0.7285180865669251], 'cation_decoded_mean_loss': [0.8488339368438721], 'loss': [1.5773520235443115], 'anion_decoded_mean_acc': [0.9045569351005555]}
# {'cation_decoded_mean_acc': [0.8987799995803833], 'anion_decoded_mean_loss': [0.6405793489360809], 'cation_decoded_mean_loss': [0.7617990865898132], 'loss': [1.4023784352111817], 'anion_decoded_mean_acc': [0.9165408066749573]}
# {'cation_decoded_mean_acc': [0.9095920970344543], 'anion_decoded_mean_loss': [0.582258890581131], 'cation_decoded_mean_loss': [0.6890968917083741], 'loss': [1.2713557824516297], 'anion_decoded_mean_acc': [0.924689838886261]}
# {'cation_decoded_mean_acc': [0.9174359679985047], 'anion_decoded_mean_loss': [0.5264070975971222], 'cation_decoded_mean_loss': [0.6323177393245697], 'loss': [1.158724837436676], 'anion_decoded_mean_acc': [0.932446289806366]}
# {'cation_decoded_mean_acc': [0.9251235485267639], 'anion_decoded_mean_loss': [0.47487737189292906], 'cation_decoded_mean_loss': [0.5775331702899933], 'loss': [1.0524105416107177], 'anion_decoded_mean_acc': [0.9395437096405029]}
# {'cation_decoded_mean_acc': [0.9575109673690796], 'anion_decoded_mean_loss': [0.3377711849531531], 'cation_decoded_mean_loss': [0.3567004822605848], 'loss': [0.6944716674345732], 'anion_decoded_mean_acc': [0.9604111284637451]}
# {'cation_decoded_mean_acc': [0.9565666125869751], 'anion_decoded_mean_loss': [0.30508187571160494], 'cation_decoded_mean_loss': [0.34488722207129], 'loss': [0.6499690982383489], 'anion_decoded_mean_acc': [0.9629769348907471]}
# {'cation_decoded_mean_acc': [0.9528300002288819], 'anion_decoded_mean_loss': [0.30209810413360594], 'cation_decoded_mean_loss': [0.38206693390518426], 'loss': [0.6841650379830598], 'anion_decoded_mean_acc': [0.9632269355964661]}
# {'cation_decoded_mean_acc': [0.9543088710784912], 'anion_decoded_mean_loss': [0.29031962243683634], 'cation_decoded_mean_loss': [0.3613756426678598], 'loss': [0.6516952653169632], 'anion_decoded_mean_acc': [0.9646351605415344]}
# {'cation_decoded_mean_acc': [0.9571291935539246], 'anion_decoded_mean_loss': [0.2817643433663249], 'cation_decoded_mean_loss': [0.3395469042161107], 'loss': [0.6213112479788065], 'anion_decoded_mean_acc': [0.9658088707542419]}
# {'cation_decoded_mean_acc': [0.9988129041290283], 'anion_decoded_mean_loss': [0.04068198474861681], 'cation_decoded_mean_loss': [0.015687746899351478], 'loss': [0.05636973175726831], 'anion_decoded_mean_acc': [0.9973162868309021]}
# {'cation_decoded_mean_acc': [0.9963643548774719], 'anion_decoded_mean_loss': [0.05147997614324093], 'cation_decoded_mean_loss': [0.04083121875923127], 'loss': [0.09231119496785105], 'anion_decoded_mean_acc': [0.9961938690757751]}
# {'cation_decoded_mean_acc': [0.9975869358444214], 'anion_decoded_mean_loss': [0.07303291653636843], 'cation_decoded_mean_loss': [0.027300447314530612], 'loss': [0.10033336374565958], 'anion_decoded_mean_acc': [0.9934933884048462]}
# {'cation_decoded_mean_acc': [0.998331612854004], 'anion_decoded_mean_loss': [0.07237965413529426], 'cation_decoded_mean_loss': [0.02130599860791117], 'loss': [0.09368565270356834], 'anion_decoded_mean_acc': [0.9936748400878906]}
# {'cation_decoded_mean_acc': [0.997559031791687], 'anion_decoded_mean_loss': [0.1456806352681294], 'cation_decoded_mean_loss': [0.028758227338474242], 'loss': [0.17443886264681815], 'anion_decoded_mean_acc': [0.9866443563461303]}

# %%
import os
histories = []
for root, dirs, files in os.walk("."):  
    for filename in files:
        if 'history' in filename:
            if '100' in filename:
                if 'viscosity' in filename:
                    histories.append(filename)
histories.sort()            
for key, item in enumerate(histories):
    try:
        print(histories[key])
        f = open("{}".format(histories[key]),"r")
        history = json.loads(f.read())

        fig, ax = plt.subplots(1, figsize=(10,10))
        ax.plot(history['val_decoded_mean_acc'], label='val acc')
        ax.plot(history['val_qspr_mean_squared_error'], label ='val qspr mse')
        ax.plot(history['decoded_mean_acc'], label = 'acc')
        ax.plot(history['qspr_mean_squared_error'], label='qspr mse')
        ax.set_ylim(0,2)
        ax.set_title(item)
        ax.legend()
    except:pass
# Out:
# history_gen2_2mol_50mil_GDB17_5_2_mix_5_2_cat_5_2_viscosity_vae_100_epochs.json
# history_gen2_2mol_50mil_GDB17_5_2_mix_5_2_viscosity_vae_100_epochs.json
# history_gen2_2mol_50mil_GDB17_5_2_viscosity_vae_100_epochs.json

# %%
import os
histories = []
for root, dirs, files in os.walk("."):  
    for filename in files:
        if 'history' in filename:
            if '100' in filename:
                if 'viscosity' in filename:
                    histories.append(filename)
histories.sort()           
for key, item in enumerate(histories):
    try:
        print(histories[key])
        f = open("{}".format(histories[key]),"r")
        history = json.loads(f.read())

        fig, ax = plt.subplots(1, figsize=(10,10))
        ax.plot(history['val_decoded_mean_acc'], label='val acc')
        ax.plot(history['val_qspr_mean_squared_error'], label ='val qspr mse')
        ax.plot(history['decoded_mean_acc'], label = 'acc')
        ax.plot(history['qspr_mean_squared_error'], label='qspr mse')
        ax.set_ylim(0,2)
        ax.set_title(item)
        ax.legend()
    except:pass
# Out:
# history_gen2_2mol_50mil_GDB17_5_2_mix_5_2_cat_5_2_viscosity_vae_100_epochs.json
# history_gen2_2mol_50mil_GDB17_5_2_mix_5_2_viscosity_vae_100_epochs.json
# history_gen2_2mol_50mil_GDB17_5_2_viscosity_vae_100_epochs.json

# %%
import os
histories = []
for root, dirs, files in os.walk("."):  
    for filename in files:
        if 'history' in filename:
            if '100' in filename:
                if 'cpt' in filename:
                    histories.append(filename)
histories.sort()           
for key, item in enumerate(histories):
    try:
        print(histories[key])
        f = open("{}".format(histories[key]),"r")
        history = json.loads(f.read())

        fig, ax = plt.subplots(1, figsize=(10,10))
        ax.plot(history['val_decoded_mean_acc'], label='val acc')
        ax.plot(history['val_qspr_mean_squared_error'], label ='val qspr mse')
        ax.plot(history['decoded_mean_acc'], label = 'acc')
        ax.plot(history['qspr_mean_squared_error'], label='qspr mse')
        ax.set_ylim(0,2)
        ax.set_title(item)
        ax.legend()
    except:pass
# Out:
# history_gen2_2mol_50mil_GDB17_5_2_cpt_vae_100_epochs.json
# history_gen2_2mol_50mil_GDB17_5_2_mix_5_2_cat_5_2_cpt_vae_100_epochs.json
# history_gen2_2mol_50mil_GDB17_5_2_mix_5_2_cpt_vae_100_epochs.json

# %%
import os
histories = []
for root, dirs, files in os.walk("."):  
    for filename in files:
        if 'history' in filename:
            if '100' in filename:
                if 'thermal' in filename:
                    histories.append(filename)
histories.sort()        
for key, item in enumerate(histories):
    try:
        print(histories[key])
        f = open("{}".format(histories[key]),"r")
        history = json.loads(f.read())

        fig, ax = plt.subplots(1, figsize=(10,10))
        ax.plot(history['val_decoded_mean_acc'], label='val acc')
        ax.plot(history['val_qspr_mean_squared_error'], label ='val qspr mse')
        ax.plot(history['decoded_mean_acc'], label = 'acc')
        ax.plot(history['qspr_mean_squared_error'], label='qspr mse')
        ax.set_ylim(0,2)
        ax.set_title(item)
        ax.legend()
    except:pass
# Out:
# history_gen2_2mol_50mil_GDB17_5_2_mix_5_2_cat_5_2_thermal_conductivity_vae_100_epochs.json
# history_gen2_2mol_50mil_GDB17_5_2_mix_5_2_thermal_conductivity_vae_100_epochs.json
# history_gen2_2mol_50mil_GDB17_5_2_thermal_conductivity_vae_100_epochs.json

# %%
import os
histories = []
for root, dirs, files in os.walk("."):  
    for filename in files:
        if 'history' in filename:
            if '100' in filename:
                if 'melting' in filename:
                    histories.append(filename)
            
for key, item in enumerate(histories):
    try:
        print(histories[key])
        f = open("{}".format(histories[key]),"r")
        history = json.loads(f.read())

        fig, ax = plt.subplots(1, figsize=(10,10))
        ax.plot(history['val_decoded_mean_acc'], label='val acc')
        ax.plot(history['val_qspr_mean_squared_error'], label ='val qspr mse')
        ax.plot(history['decoded_mean_acc'], label = 'acc')
        ax.plot(history['qspr_mean_squared_error'], label='qspr mse')
        ax.set_ylim(0,2)
        ax.set_title(item)
        ax.legend()
    except:pass
# Out:
# history_gen2_2mol_50mil_GDB17_5_2_melting_point_vae_100_epochs.json
# history_gen2_2mol_50mil_GDB17_5_2_mix_5_2_cat_5_2_melting_point_vae_100_epochs.json
# history_gen2_2mol_50mil_GDB17_5_2_mix_5_2_melting_point_vae_100_epochs.json

# %%
#first million
phase_1a_history = {'acc': [0.6336, 0.6586, 0.6635, 0.6670, 0.6718, 0.6767, 0.6618, 0.6443, 0.6454, 0.6460],
                   'val_acc': [0.6578, 0.6611, 0.6604, 0.6683, 0.6703, 0.6829, 0.6437, 0.6448, 0.6459, 0.6493]}
plt.plot(phase_1a_history['acc'], label='acc')
plt.plot(phase_1a_history['val_acc'], label='val_acc')
plt.legend()
plt.title('First Million GDB, 2 molecule output')
# Out:
# Text(0.5,1,'First Million GDB, 2 molecule output')

# %%
#1-6million
phase_1b_history = {'acc': [0.6447, 0.6578, 0.6644, 0.6681, 0.6703, 0.6713, 0.6703, 0.6067, 0.6339, 0.6621],
                   'val_acc': [0.6547, 0.6634, 0.6397, 0.6564, 0.6728, 0.6667, 0.6729, 0.6447, 0.6592, 0.6673]}
plt.plot(phase_1b_history['acc'], label='acc')
plt.plot(phase_1b_history['val_acc'], label='val_acc')
plt.legend()
plt.title('6 million GDB, 2 molecule output')
# Out:
# Text(0.5,1,'6 million GDB, 2 molecule output')

# %%
phase_2_history = {'acc': [0.3916, 0.4049, 0.4382, 0.4489, 0.4662, 0.4804, 0.4726, 0.4956, 0.4841, 0.4940],
                   'val_acc': [0.3806, 0.4983, 0.4383, 0.4809, 0.4735, 0.4200, 0.4958, 0.4972, 0.5109, 0.4974]}
plt.plot(phase_2_history['acc'], label='acc')
plt.plot(phase_2_history['val_acc'], label='val_acc')
plt.legend()
plt.title('5 million mix training, 2 molecule output')
# Out:
# Text(0.5,1,'5 million mix training, 2 molecule output')

# %%
phase_3_history = {'acc': [0.3774, 0.3258, 0.3169, 0.3039, 0.3278, 0.3511, 0.3161, 0.3214, 0.3438, 0.3268],
                   'val_acc': [0.4245, 0.3295, 0.3228, 0.3254, 0.3882, 0.3214, 0.2852, 0.3536, 0.3306]}
plt.plot(phase_3_history['acc'], label='acc')
plt.plot(phase_3_history['val_acc'], label='val_acc')
plt.legend()
plt.title('5 million salt training, 2 molecule output')
# Out:
# Text(0.5,1,'5 million salt training, 2 molecule output')

# %%
single_phase_1_history = {'acc': [0.6586, 0.7494, 0.7994, 0.8279, 0.8491, 0.8634, 0.8743, 0.8868, 0.8925, 0.8996],
                   'val_acc': [0.7072, 0.7752, 0.8137, 0.8387, 0.8551, 0.8722, 0.8686, 0.8906, 0.9009, 0.8998]}
plt.plot(single_phase_1_history['acc'], label='acc')
plt.plot(single_phase_1_history['val_acc'], label='val_acc')
plt.legend()
plt.title('First Million GDB, 1 molecule output')
# Out:
# Text(0.5,1,'First Million GDB, 1 molecule output')

# %%
single_phase_3_history = {'acc': [0.4552, 0.4598, 0.4697, 0.4566, 0.4664],
                   'val_acc': [0.4405, 0.4548, 0.4523, 0.4384, 0.4500]}
plt.plot(single_phase_3_history['acc'], label='acc')
plt.plot(single_phase_3_history['val_acc'], label='val_acc')
plt.legend()
